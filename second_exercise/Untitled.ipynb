# %%
from __future__ import division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn import preprocessing

# %%
hands = np.loadtxt('C:\Users\Taneli\Downloads\data_analysis\second_exercise\shapes.txt')
#Sigma = np.cov(hands)
#hands = np.ndarray.transpose(hands)
mean_hand = hands[:,0]
x = hands[range(0,56)]
y = hands[range(56,112)]
plt.plot(x,y)
#x = mean_hand[range(0,56)]
#y = mean_hand[range(56,112)]
#plt.plot(x,y)

#for i in range(len(array_3)):
#    plotface(array_3[i], i)
# Out:
# [<matplotlib.lines.Line2D at 0x9e8e630>,
#  <matplotlib.lines.Line2D at 0x9e8e7f0>,
#  <matplotlib.lines.Line2D at 0x9e8e908>,
#  <matplotlib.lines.Line2D at 0x9e8ea20>,
#  <matplotlib.lines.Line2D at 0x9e8eb38>,
#  <matplotlib.lines.Line2D at 0x9e8ec50>,
#  <matplotlib.lines.Line2D at 0x9e8ed68>,
#  <matplotlib.lines.Line2D at 0xaef7748>,
#  <matplotlib.lines.Line2D at 0x9e8ef98>,
#  <matplotlib.lines.Line2D at 0x9cd90f0>,
#  <matplotlib.lines.Line2D at 0x9cd9208>,
#  <matplotlib.lines.Line2D at 0x9cd9320>,
#  <matplotlib.lines.Line2D at 0x9cd9438>,
#  <matplotlib.lines.Line2D at 0x9cd9550>,
#  <matplotlib.lines.Line2D at 0x9e8ee80>,
#  <matplotlib.lines.Line2D at 0x9cd9780>,
#  <matplotlib.lines.Line2D at 0x9cd9898>,
#  <matplotlib.lines.Line2D at 0x9cd99b0>,
#  <matplotlib.lines.Line2D at 0x9cd9ac8>,
#  <matplotlib.lines.Line2D at 0x9cd9be0>,
#  <matplotlib.lines.Line2D at 0x9cd9cf8>,
#  <matplotlib.lines.Line2D at 0x9cd9668>,
#  <matplotlib.lines.Line2D at 0x9cd9f28>,
#  <matplotlib.lines.Line2D at 0x9cfa080>,
#  <matplotlib.lines.Line2D at 0x9cfa198>,
#  <matplotlib.lines.Line2D at 0x9cfa2b0>,
#  <matplotlib.lines.Line2D at 0x9cfa3c8>,
#  <matplotlib.lines.Line2D at 0x9cfa4e0>,
#  <matplotlib.lines.Line2D at 0x9cd9e10>,
#  <matplotlib.lines.Line2D at 0x9cfa710>,
#  <matplotlib.lines.Line2D at 0x9cfa828>,
#  <matplotlib.lines.Line2D at 0x9cfa940>,
#  <matplotlib.lines.Line2D at 0x9cfaa58>,
#  <matplotlib.lines.Line2D at 0x9cfab70>,
#  <matplotlib.lines.Line2D at 0x9cfac88>,
#  <matplotlib.lines.Line2D at 0x9cfa5f8>,
#  <matplotlib.lines.Line2D at 0x9cfaeb8>,
#  <matplotlib.lines.Line2D at 0x9cfafd0>,
#  <matplotlib.lines.Line2D at 0x9ce5128>,
#  <matplotlib.lines.Line2D at 0x9ce5240>]
